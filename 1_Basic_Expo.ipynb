# %% [markdown]
# ## Import the libraries

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('Sample - Superstore.csv', encoding= 'latin1' )

# %%
print(df.shape)
# Out:
# (9994, 21)

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.count()
# Out:
# Row ID           9994
# Order ID         9994
# Order Date       9994
# Ship Date        9994
# Ship Mode        9994
# Customer ID      9994
# Customer Name    9994
# Segment          9994
# Country          9994
# City             9994
# State            9994
# Postal Code      9994
# Region           9994
# Product ID       9994
# Category         9994
# Sub-Category     9994
# Product Name     9994
# Sales            9994
# Quantity         9994
# Discount         9994
# Profit           9994
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Group1.  Basic Exploration + loc/iloc

# %% [markdown]
# ### Q1. Show the first 5 rows

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### Q2. Show the last 3 rows

# %%
df.tail(3)
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 9991    9992  CA-2017-121258  2/26/2017  3/3/2017  Standard Class    DB-13060
# 9992    9993  CA-2017-121258  2/26/2017  3/3/2017  Standard Class    DB-13060
# 9993    9994  CA-2017-119914   5/4/2017  5/9/2017    Second Class    CC-12220
#
#      Customer Name   Segment        Country         City  ... Postal Code  \
# 9991   Dave Brooks  Consumer  United States   Costa Mesa  ...       92627
# 9992   Dave Brooks  Consumer  United States   Costa Mesa  ...       92627
# 9993  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#       Region       Product ID         Category Sub-Category  \
# 9991    West  TEC-PH-10003645       Technology       Phones
# 9992    West  OFF-PA-10004041  Office Supplies        Paper
# 9993    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# ...

# %% [markdown]
# ### Q3. Select only columns: Customer Name, Category, Sales, Profit

# %%
df[['Customer Name', 'Category', 'Sales', 'Profit']]
# Out:
#          Customer Name         Category     Sales    Profit
# 0          Claire Gute        Furniture  261.9600   41.9136
# 1          Claire Gute        Furniture  731.9400  219.5820
# 2      Darrin Van Huff  Office Supplies   14.6200    6.8714
# 3       Sean O'Donnell        Furniture  957.5775 -383.0310
# 4       Sean O'Donnell  Office Supplies   22.3680    2.5164
# ...                ...              ...       ...       ...
# 9989  Tom Boeckenhauer        Furniture   25.2480    4.1028
# 9990       Dave Brooks        Furniture   91.9600   15.6332
# 9991       Dave Brooks       Technology  258.5760   19.3932
# 9992       Dave Brooks  Office Supplies   29.6000   13.3200
# 9993      Chris Cortes  Office Supplies  243.1600   72.9480
#
# [9994 rows x 4 columns]

# %% [markdown]
# ### Q4. Using iloc — select rows 10 to 20, columns 0 to 4

# %%
df.iloc[10:21, 0:4]
# Out:
#     Row ID        Order ID  Order Date   Ship Date
# 10      11  CA-2014-115812    6/9/2014   6/14/2014
# 11      12  CA-2014-115812    6/9/2014   6/14/2014
# 12      13  CA-2017-114412   4/15/2017   4/20/2017
# 13      14  CA-2016-161389   12/5/2016  12/10/2016
# 14      15  US-2015-118983  11/22/2015  11/26/2015
# 15      16  US-2015-118983  11/22/2015  11/26/2015
# 16      17  CA-2014-105893  11/11/2014  11/18/2014
# 17      18  CA-2014-167164   5/13/2014   5/15/2014
# 18      19  CA-2014-143336   8/27/2014    9/1/2014
# 19      20  CA-2014-143336   8/27/2014    9/1/2014
# 20      21  CA-2014-143336   8/27/2014    9/1/2014

# %% [markdown]
# ### Q5. Using loc — select rows where index is 5, show only 'Customer Name' and 'Sales'

# %%
df.loc[5,['Customer Name','Sales']]
# Out:
# Customer Name    Brosina Hoffman
# Sales                      48.86
# Name: 5, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ---
